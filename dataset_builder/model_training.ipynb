# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import pathlib
import tensorflow as tf 
import os
import datetime

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
data_dir = pathlib.Path("dataset").with_suffix("")
image_count = len(list(data_dir.glob("*/*.jpg")))
print("Found {} images".format(image_count))
# Out:
# Found 2572 images

# %%
eyes_open = list(data_dir.glob("eyes_open/*"))
PIL.Image.open(str(eyes_open[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=316x240>

# %%
batch_size = 100
img_height = 30
img_width = 50

# %%
training_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split = 0.3,
  subset = "training",
  seed=123,
  image_size = (img_height, img_width),
  batch_size = batch_size,
  shuffle=True,
  labels="inferred",
  color_mode="rgb"
)
validation_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split = 0.3,
  subset = "validation",
  seed = 123,
  image_size = (img_height, img_width),
  batch_size=batch_size,
  shuffle=True,
  labels="inferred",
  color_mode="rgb"
)
# Out:
# Found 2572 files belonging to 2 classes.
# Using 1801 files for training.
# Found 2572 files belonging to 2 classes.
# Using 771 files for validation.

# %%
class_names = training_dataset.class_names
print("Using class names with length {}".format(len(class_names)))
print(class_names)
# Out:
# Using class names with length 2
# ['eyes_closed', 'eyes_open']

# %%
plt.figure(figsize=(5, 5))
for images, labels in training_dataset.take(1):
  for i in range(2):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# 2024-05-16 10:27:21.974496: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# 32 is the amount of images in a single training batch
# 80 and 50 is the width and height of the image
# 3 is the array of the pixel which contains tha Red Green and Blue values

# %%
for image_batch, labels_batch in training_dataset:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (100, 30, 50, 3)
# (100,)

# %%
AUTOTUNE = tf.data.AUTOTUNE
training_dataset = training_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)

# %%
#normalize layers which turns 0 ,255 to 0, 1
normalization_layer = layers.Rescaling(1./255)
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal_and_vertical",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.4),
    layers.RandomBrightness(0.4),
  ]
)
# Out:
# /Users/christianharjuno/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/layers/preprocessing/tf_data_layer.py:18: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
classes_amount = len(class_names)

# %%
plt.figure(figsize=(2, 2))
for images, _ in training_dataset.take(1):
  for i in range(4):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(2, 2, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# 2024-05-16 10:27:22.464000: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
tf.keras.backend.clear_session()
model = Sequential([
  normalization_layer,
  layers.Conv2D(16, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D((2, 2)),
  layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D((2, 2)),
  layers.Dropout(0.5),
  layers.Flatten(),
  layers.Dense(32,  activation="relu"),
  layers.Dense(classes_amount, activation="softmax"),
])

# %%
model.build()
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# %%
epochs = 150
tf.keras.backend.clear_session()
history = model.fit(
  training_dataset,
  validation_data=validation_dataset,
  epochs=epochs,
  callbacks=[tensorboard_callback]
)
model.summary()
# Out:
# Epoch 1/150
# /Users/christianharjuno/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py:602: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5418 - loss: 0.6892 - val_accuracy: 0.5564 - val_loss: 0.6816
# Epoch 2/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5618 - loss: 0.6819 - val_accuracy: 0.5564 - val_loss: 0.6771
# Epoch 3/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5507 - loss: 0.6857 - val_accuracy: 0.5785 - val_loss: 0.6750
# Epoch 4/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5629 - loss: 0.6751 - val_accuracy: 0.5850 - val_loss: 0.6694
# Epoch 5/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5672 - loss: 0.6750 - val_accuracy: 0.6265 - val_loss: 0.6596
# Epoch 6/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5785 - loss: 0.6635 - val_accuracy: 0.8054 - val_loss: 0.6544
# Epoch 7/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6417 - loss: 0.6581 - val_accuracy: 0.8327 - val_loss: 0.6411
# Epoch 8/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6666 - loss: 0.6430 - val_accuracy: 0.8495 - val_loss: 0.6257
# Epoch 9/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6449 - loss: 0.6345 - val_accuracy: 0.8690 - val_loss: 0.6080
# Epoch 10/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7216 - loss: 0.6117 - val_accuracy: 0.8651 - val_loss: 0.5834
# Epoch 11/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7781 - loss: 0.5943 - val_accuracy: 0.8677 - val_loss: 0.5574
# Epoch 12/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7477 - loss: 0.5600 - val_accuracy: 0.9261 - val_loss: 0.5130
# Epoch 13/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8266 - loss: 0.5197 - val_accuracy: 0.9572 - val_loss: 0.4809
# Epoch 14/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8955 - loss: 0.4965 - val_accuracy: 0.9040 - val_loss: 0.4466
# Epoch 15/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8802 - loss: 0.4564 - val_accuracy: 0.9351 - val_loss: 0.4011
# Epoch 16/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8989 - loss: 0.4102 - val_accuracy: 0.9650 - val_loss: 0.3674
# Epoch 17/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9268 - loss: 0.3784 - val_accuracy: 0.9624 - val_loss: 0.3232
# Epoch 18/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9319 - loss: 0.3478 - val_accuracy: 0.9559 - val_loss: 0.2929
# Epoch 19/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9404 - loss: 0.3076 - val_accuracy: 0.9624 - val_loss: 0.2640
# Epoch 20/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9507 - loss: 0.2789 - val_accuracy: 0.9624 - val_loss: 0.2394
# Epoch 21/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9423 - loss: 0.2648 - val_accuracy: 0.9624 - val_loss: 0.2183
# Epoch 22/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9459 - loss: 0.2463 - val_accuracy: 0.9546 - val_loss: 0.2136
# Epoch 23/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9581 - loss: 0.2081 - val_accuracy: 0.9637 - val_loss: 0.1848
# Epoch 24/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9579 - loss: 0.2011 - val_accuracy: 0.9650 - val_loss: 0.1741
# Epoch 25/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9558 - loss: 0.1949 - val_accuracy: 0.9624 - val_loss: 0.1610
# Epoch 26/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9584 - loss: 0.1788 - val_accuracy: 0.9676 - val_loss: 0.1654
# Epoch 27/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9533 - loss: 0.1864 - val_accuracy: 0.9624 - val_loss: 0.1443
# Epoch 28/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9563 - loss: 0.1736 - val_accuracy: 0.9598 - val_loss: 0.1453
# Epoch 29/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9556 - loss: 0.1575 - val_accuracy: 0.9650 - val_loss: 0.1315
# Epoch 30/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9555 - loss: 0.1515 - val_accuracy: 0.9650 - val_loss: 0.1272
# Epoch 31/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9562 - loss: 0.1666 - val_accuracy: 0.9650 - val_loss: 0.1239
# Epoch 32/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9564 - loss: 0.1523 - val_accuracy: 0.9650 - val_loss: 0.1215
# Epoch 33/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9600 - loss: 0.1427 - val_accuracy: 0.9637 - val_loss: 0.1202
# Epoch 34/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9512 - loss: 0.1571 - val_accuracy: 0.9611 - val_loss: 0.1262
# Epoch 35/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9592 - loss: 0.1372 - val_accuracy: 0.9650 - val_loss: 0.1146
# Epoch 36/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9626 - loss: 0.1289 - val_accuracy: 0.9624 - val_loss: 0.1185
# Epoch 37/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9626 - loss: 0.1308 - val_accuracy: 0.9650 - val_loss: 0.1116
# Epoch 38/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9542 - loss: 0.1558 - val_accuracy: 0.9637 - val_loss: 0.1141
# Epoch 39/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9640 - loss: 0.1249 - val_accuracy: 0.9624 - val_loss: 0.1143
# Epoch 40/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9530 - loss: 0.1413 - val_accuracy: 0.9650 - val_loss: 0.1072
# Epoch 41/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9655 - loss: 0.1192 - val_accuracy: 0.9637 - val_loss: 0.1114
# Epoch 42/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9621 - loss: 0.1190 - val_accuracy: 0.9650 - val_loss: 0.1130
# Epoch 43/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9625 - loss: 0.1239 - val_accuracy: 0.9650 - val_loss: 0.1080
# Epoch 44/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9636 - loss: 0.1164 - val_accuracy: 0.9650 - val_loss: 0.1105
# Epoch 45/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9652 - loss: 0.1082 - val_accuracy: 0.9663 - val_loss: 0.1061
# Epoch 46/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9572 - loss: 0.1127 - val_accuracy: 0.9663 - val_loss: 0.1051
# Epoch 47/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9543 - loss: 0.1217 - val_accuracy: 0.9650 - val_loss: 0.1100
# Epoch 48/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9625 - loss: 0.1027 - val_accuracy: 0.9624 - val_loss: 0.1156
# Epoch 49/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9618 - loss: 0.1159 - val_accuracy: 0.9611 - val_loss: 0.1239
# Epoch 50/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9581 - loss: 0.1287 - val_accuracy: 0.9650 - val_loss: 0.1077
# Epoch 51/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9619 - loss: 0.1288 - val_accuracy: 0.9663 - val_loss: 0.1008
# Epoch 52/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9673 - loss: 0.1163 - val_accuracy: 0.9637 - val_loss: 0.1129
# Epoch 53/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9571 - loss: 0.1221 - val_accuracy: 0.9663 - val_loss: 0.0988
# Epoch 54/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9634 - loss: 0.1122 - val_accuracy: 0.9650 - val_loss: 0.1045
# Epoch 55/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9640 - loss: 0.1151 - val_accuracy: 0.9663 - val_loss: 0.1030
# Epoch 56/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9673 - loss: 0.0956 - val_accuracy: 0.9637 - val_loss: 0.1145
# Epoch 57/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9635 - loss: 0.1222 - val_accuracy: 0.9663 - val_loss: 0.1001
# Epoch 58/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9655 - loss: 0.1137 - val_accuracy: 0.9676 - val_loss: 0.0956
# Epoch 59/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9675 - loss: 0.1003 - val_accuracy: 0.9663 - val_loss: 0.0997
# Epoch 60/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9643 - loss: 0.1077 - val_accuracy: 0.9663 - val_loss: 0.0978
# Epoch 61/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9630 - loss: 0.1158 - val_accuracy: 0.9650 - val_loss: 0.1066
# Epoch 62/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9678 - loss: 0.1044 - val_accuracy: 0.9676 - val_loss: 0.0942
# Epoch 63/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9679 - loss: 0.1080 - val_accuracy: 0.9689 - val_loss: 0.0937
# Epoch 64/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9636 - loss: 0.1061 - val_accuracy: 0.9663 - val_loss: 0.1058
# Epoch 65/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9598 - loss: 0.1153 - val_accuracy: 0.9663 - val_loss: 0.1003
# Epoch 66/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9660 - loss: 0.0938 - val_accuracy: 0.9676 - val_loss: 0.0950
# Epoch 67/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9690 - loss: 0.0987 - val_accuracy: 0.9676 - val_loss: 0.1003
# Epoch 68/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9624 - loss: 0.1049 - val_accuracy: 0.9689 - val_loss: 0.0953
# Epoch 69/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9716 - loss: 0.0891 - val_accuracy: 0.9676 - val_loss: 0.1020
# Epoch 70/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9670 - loss: 0.1017 - val_accuracy: 0.9715 - val_loss: 0.0899
# Epoch 71/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9661 - loss: 0.1102 - val_accuracy: 0.9702 - val_loss: 0.0953
# Epoch 72/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9678 - loss: 0.0970 - val_accuracy: 0.9676 - val_loss: 0.0990
# Epoch 73/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9752 - loss: 0.0855 - val_accuracy: 0.9702 - val_loss: 0.0930
# Epoch 74/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9728 - loss: 0.0815 - val_accuracy: 0.9637 - val_loss: 0.1024
# Epoch 75/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9719 - loss: 0.0964 - val_accuracy: 0.9702 - val_loss: 0.0934
# Epoch 76/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9725 - loss: 0.0864 - val_accuracy: 0.9624 - val_loss: 0.1026
# Epoch 77/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9691 - loss: 0.1046 - val_accuracy: 0.9689 - val_loss: 0.0951
# Epoch 78/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9664 - loss: 0.0951 - val_accuracy: 0.9702 - val_loss: 0.0926
# Epoch 79/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9751 - loss: 0.0813 - val_accuracy: 0.9702 - val_loss: 0.0857
# Epoch 80/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9616 - loss: 0.0964 - val_accuracy: 0.9728 - val_loss: 0.0869
# Epoch 81/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9735 - loss: 0.0873 - val_accuracy: 0.9689 - val_loss: 0.0916
# Epoch 82/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9753 - loss: 0.0717 - val_accuracy: 0.9663 - val_loss: 0.0989
# Epoch 83/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9641 - loss: 0.0991 - val_accuracy: 0.9611 - val_loss: 0.1057
# Epoch 84/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9687 - loss: 0.0893 - val_accuracy: 0.9702 - val_loss: 0.0894
# Epoch 85/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9662 - loss: 0.0926 - val_accuracy: 0.9741 - val_loss: 0.0842
# Epoch 86/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9758 - loss: 0.0848 - val_accuracy: 0.9689 - val_loss: 0.0902
# Epoch 87/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9687 - loss: 0.0981 - val_accuracy: 0.9611 - val_loss: 0.1052
# Epoch 88/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9747 - loss: 0.0823 - val_accuracy: 0.9715 - val_loss: 0.0866
# Epoch 89/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9716 - loss: 0.0938 - val_accuracy: 0.9650 - val_loss: 0.0991
# Epoch 90/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9694 - loss: 0.0901 - val_accuracy: 0.9689 - val_loss: 0.0907
# Epoch 91/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9801 - loss: 0.0781 - val_accuracy: 0.9689 - val_loss: 0.0901
# Epoch 92/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9743 - loss: 0.0823 - val_accuracy: 0.9728 - val_loss: 0.0840
# Epoch 93/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9758 - loss: 0.0899 - val_accuracy: 0.9663 - val_loss: 0.0973
# Epoch 94/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9759 - loss: 0.0748 - val_accuracy: 0.9663 - val_loss: 0.0936
# Epoch 95/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9736 - loss: 0.0808 - val_accuracy: 0.9663 - val_loss: 0.0933
# Epoch 96/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9715 - loss: 0.0891 - val_accuracy: 0.9728 - val_loss: 0.0826
# Epoch 97/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9705 - loss: 0.0805 - val_accuracy: 0.9715 - val_loss: 0.0838
# Epoch 98/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9690 - loss: 0.0846 - val_accuracy: 0.9663 - val_loss: 0.0964
# Epoch 99/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9695 - loss: 0.0881 - val_accuracy: 0.9728 - val_loss: 0.0865
# Epoch 100/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9762 - loss: 0.0787 - val_accuracy: 0.9689 - val_loss: 0.0918
# Epoch 101/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9745 - loss: 0.0886 - val_accuracy: 0.9715 - val_loss: 0.0845
# Epoch 102/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9767 - loss: 0.0826 - val_accuracy: 0.9702 - val_loss: 0.0887
# Epoch 103/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9693 - loss: 0.0906 - val_accuracy: 0.9689 - val_loss: 0.0916
# Epoch 104/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9690 - loss: 0.0975 - val_accuracy: 0.9650 - val_loss: 0.0971
# Epoch 105/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9782 - loss: 0.0755 - val_accuracy: 0.9715 - val_loss: 0.0828
# Epoch 106/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9664 - loss: 0.0813 - val_accuracy: 0.9689 - val_loss: 0.0934
# Epoch 107/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9733 - loss: 0.0868 - val_accuracy: 0.9728 - val_loss: 0.0849
# Epoch 108/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9737 - loss: 0.0833 - val_accuracy: 0.9715 - val_loss: 0.0808
# Epoch 109/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9762 - loss: 0.0776 - val_accuracy: 0.9728 - val_loss: 0.0798
# Epoch 110/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9738 - loss: 0.0916 - val_accuracy: 0.9728 - val_loss: 0.0836
# Epoch 111/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9790 - loss: 0.0733 - val_accuracy: 0.9715 - val_loss: 0.0807
# Epoch 112/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9665 - loss: 0.0899 - val_accuracy: 0.9676 - val_loss: 0.0937
# Epoch 113/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9770 - loss: 0.0683 - val_accuracy: 0.9715 - val_loss: 0.0794
# Epoch 114/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9752 - loss: 0.0636 - val_accuracy: 0.9728 - val_loss: 0.0864
# Epoch 115/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9772 - loss: 0.0796 - val_accuracy: 0.9741 - val_loss: 0.0790
# Epoch 116/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9767 - loss: 0.0641 - val_accuracy: 0.9715 - val_loss: 0.0828
# Epoch 117/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9766 - loss: 0.0732 - val_accuracy: 0.9702 - val_loss: 0.0845
# Epoch 118/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9742 - loss: 0.0785 - val_accuracy: 0.9715 - val_loss: 0.0831
# Epoch 119/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9748 - loss: 0.0748 - val_accuracy: 0.9702 - val_loss: 0.0853
# Epoch 120/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9762 - loss: 0.0740 - val_accuracy: 0.9689 - val_loss: 0.0903
# Epoch 121/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9655 - loss: 0.0944 - val_accuracy: 0.9728 - val_loss: 0.0775
# Epoch 122/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9761 - loss: 0.0682 - val_accuracy: 0.9715 - val_loss: 0.0865
# Epoch 123/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9760 - loss: 0.0789 - val_accuracy: 0.9689 - val_loss: 0.0927
# Epoch 124/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9633 - loss: 0.1058 - val_accuracy: 0.9728 - val_loss: 0.0776
# Epoch 125/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9741 - loss: 0.0867 - val_accuracy: 0.9728 - val_loss: 0.0792
# Epoch 126/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9750 - loss: 0.0729 - val_accuracy: 0.9728 - val_loss: 0.0842
# Epoch 127/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9735 - loss: 0.0758 - val_accuracy: 0.9715 - val_loss: 0.0802
# Epoch 128/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9762 - loss: 0.0733 - val_accuracy: 0.9637 - val_loss: 0.0966
# Epoch 129/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9677 - loss: 0.0935 - val_accuracy: 0.9728 - val_loss: 0.0835
# Epoch 130/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9709 - loss: 0.0885 - val_accuracy: 0.9715 - val_loss: 0.0815
# Epoch 131/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9754 - loss: 0.0688 - val_accuracy: 0.9715 - val_loss: 0.0823
# Epoch 132/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9725 - loss: 0.0721 - val_accuracy: 0.9741 - val_loss: 0.0782
# Epoch 133/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9754 - loss: 0.0883 - val_accuracy: 0.9676 - val_loss: 0.0916
# Epoch 134/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9747 - loss: 0.0683 - val_accuracy: 0.9741 - val_loss: 0.0759
# Epoch 135/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9717 - loss: 0.0882 - val_accuracy: 0.9728 - val_loss: 0.0812
# Epoch 136/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9784 - loss: 0.0716 - val_accuracy: 0.9728 - val_loss: 0.0795
# Epoch 137/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9768 - loss: 0.0804 - val_accuracy: 0.9715 - val_loss: 0.0849
# Epoch 138/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9748 - loss: 0.0804 - val_accuracy: 0.9728 - val_loss: 0.0794
# Epoch 139/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9791 - loss: 0.0704 - val_accuracy: 0.9728 - val_loss: 0.0802
# Epoch 140/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9746 - loss: 0.0801 - val_accuracy: 0.9728 - val_loss: 0.0750
# Epoch 141/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9827 - loss: 0.0725 - val_accuracy: 0.9663 - val_loss: 0.0917
# Epoch 142/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9753 - loss: 0.0781 - val_accuracy: 0.9741 - val_loss: 0.0779
# Epoch 143/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9758 - loss: 0.0716 - val_accuracy: 0.9728 - val_loss: 0.0786
# Epoch 144/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9762 - loss: 0.0748 - val_accuracy: 0.9676 - val_loss: 0.0901
# Epoch 145/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9802 - loss: 0.0649 - val_accuracy: 0.9715 - val_loss: 0.0850
# Epoch 146/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9789 - loss: 0.0663 - val_accuracy: 0.9715 - val_loss: 0.0843
# Epoch 147/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9742 - loss: 0.0830 - val_accuracy: 0.9728 - val_loss: 0.0791
# Epoch 148/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9807 - loss: 0.0651 - val_accuracy: 0.9715 - val_loss: 0.0822
# Epoch 149/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9758 - loss: 0.0806 - val_accuracy: 0.9715 - val_loss: 0.0750
# Epoch 150/150
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9695 - loss: 0.0848 - val_accuracy: 0.9728 - val_loss: 0.0825
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ ?                      │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │        86,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 273,608 (1.04 MB)
#  Trainable params: 91,202 (356.26 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 182,406 (712.53 KB)

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
img = tf.keras.utils.load_img(
    "samples/29.jpg", target_size=(img_height, img_width), color_mode="rgb"
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
print(predictions)
model.save("trained.keras")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# This image most likely belongs to eyes_closed with a 71.88 percent confidence.
# [[0.9692421  0.03075795]]
