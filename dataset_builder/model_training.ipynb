# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import pathlib
import tensorflow as tf 
import os
import datetime

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
data_dir = pathlib.Path("dataset").with_suffix("")
image_count = len(list(data_dir.glob("*/*.jpg")))
print("Found {} images".format(image_count))
# Out:
# Found 2572 images

# %%
eyes_open = list(data_dir.glob("eyes_open/*"))
PIL.Image.open(str(eyes_open[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=316x240>

# %%
batch_size = 100
img_height = 30
img_width = 50

# %%
training_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split = 0.2,
  subset = "training",
  seed=123,
  image_size = (img_height, img_width),
  batch_size = batch_size,
  shuffle=True,
  labels="inferred",
  color_mode="rgb"
)
validation_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split = 0.2,
  subset = "validation",
  seed = 123,
  image_size = (img_height, img_width),
  batch_size=batch_size,
  shuffle=True,
  labels="inferred",
  color_mode="rgb"
)
# Out:
# Found 2572 files belonging to 2 classes.
# Using 2058 files for training.
# Found 2572 files belonging to 2 classes.
# Using 514 files for validation.

# %%
class_names = training_dataset.class_names
print("Using class names with length {}".format(len(class_names)))
print(class_names)
# Out:
# Using class names with length 2
# ['eyes_closed', 'eyes_open']

# %%
plt.figure(figsize=(5, 5))
for images, labels in training_dataset.take(1):
  for i in range(2):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# 2024-05-08 20:18:22.936864: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# 32 is the amount of images in a single training batch
# 80 and 50 is the width and height of the image
# 3 is the array of the pixel which contains tha Red Green and Blue values

# %%
for image_batch, labels_batch in training_dataset:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (100, 30, 50, 3)
# (100,)

# %%
AUTOTUNE = tf.data.AUTOTUNE
training_dataset = training_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)

# %%
#normalize layers which turns 0 ,255 to 0, 1
normalization_layer = layers.Rescaling(1./255)
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal_and_vertical",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.4),
    layers.RandomBrightness(0.4),
  ]
)
# Out:
# /Users/christianharjuno/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/layers/preprocessing/tf_data_layer.py:18: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
classes_amount = len(class_names)

# %%
plt.figure(figsize=(2, 2))
for images, _ in training_dataset.take(1):
  for i in range(4):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(2, 2, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# 2024-05-08 20:18:23.539971: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
tf.keras.backend.clear_session()
model = Sequential([
  normalization_layer,
  layers.Conv2D(16, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D((2, 2)),
  layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D((2, 2)),
  layers.Dropout(0.5),
  layers.Flatten(),
  layers.Dense(32,  activation="softmax"),
  layers.Dense(classes_amount),
])

# %%
model.build()
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# %%
epochs = 150
tf.keras.backend.clear_session()
history = model.fit(
  training_dataset,
  validation_data=validation_dataset,
  epochs=epochs,
  callbacks=[tensorboard_callback]
)
model.summary()
# Out:
# Epoch 1/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.4614 - loss: 0.6941 - val_accuracy: 0.5506 - val_loss: 0.6903
# Epoch 2/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5619 - loss: 0.6887 - val_accuracy: 0.5506 - val_loss: 0.6877
# Epoch 3/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5735 - loss: 0.6834 - val_accuracy: 0.5506 - val_loss: 0.6866
# Epoch 4/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5471 - loss: 0.6871 - val_accuracy: 0.5506 - val_loss: 0.6854
# Epoch 5/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5623 - loss: 0.6828 - val_accuracy: 0.5506 - val_loss: 0.6837
# Epoch 6/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5507 - loss: 0.6836 - val_accuracy: 0.5506 - val_loss: 0.6812
# Epoch 7/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5633 - loss: 0.6779 - val_accuracy: 0.5506 - val_loss: 0.6779
# Epoch 8/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5681 - loss: 0.6727 - val_accuracy: 0.5506 - val_loss: 0.6727
# Epoch 9/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5760 - loss: 0.6650 - val_accuracy: 0.5506 - val_loss: 0.6640
# Epoch 10/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5480 - loss: 0.6623 - val_accuracy: 0.5506 - val_loss: 0.6501
# Epoch 11/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6066 - loss: 0.6453 - val_accuracy: 0.5525 - val_loss: 0.6311
# Epoch 12/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6971 - loss: 0.6231 - val_accuracy: 0.9105 - val_loss: 0.6094
# Epoch 13/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8329 - loss: 0.6083 - val_accuracy: 0.9105 - val_loss: 0.5890
# Epoch 14/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8633 - loss: 0.5878 - val_accuracy: 0.9222 - val_loss: 0.5692
# Epoch 15/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8849 - loss: 0.5662 - val_accuracy: 0.9436 - val_loss: 0.5482
# Epoch 16/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8993 - loss: 0.5538 - val_accuracy: 0.9455 - val_loss: 0.5299
# Epoch 17/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9053 - loss: 0.5337 - val_accuracy: 0.9475 - val_loss: 0.5136
# Epoch 18/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9235 - loss: 0.5186 - val_accuracy: 0.9514 - val_loss: 0.4989
# Epoch 19/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9431 - loss: 0.5048 - val_accuracy: 0.9494 - val_loss: 0.4858
# Epoch 20/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9424 - loss: 0.4900 - val_accuracy: 0.9494 - val_loss: 0.4735
# Epoch 21/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9472 - loss: 0.4775 - val_accuracy: 0.9572 - val_loss: 0.4630
# Epoch 22/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9472 - loss: 0.4704 - val_accuracy: 0.9572 - val_loss: 0.4546
# Epoch 23/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9536 - loss: 0.4588 - val_accuracy: 0.9572 - val_loss: 0.4460
# Epoch 24/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9464 - loss: 0.4527 - val_accuracy: 0.9514 - val_loss: 0.4378
# Epoch 25/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9508 - loss: 0.4423 - val_accuracy: 0.9553 - val_loss: 0.4314
# Epoch 26/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9591 - loss: 0.4331 - val_accuracy: 0.9611 - val_loss: 0.4261
# Epoch 27/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9584 - loss: 0.4312 - val_accuracy: 0.9572 - val_loss: 0.4202
# Epoch 28/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9555 - loss: 0.4254 - val_accuracy: 0.9514 - val_loss: 0.4153
# Epoch 29/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9598 - loss: 0.4154 - val_accuracy: 0.9514 - val_loss: 0.4110
# Epoch 30/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9575 - loss: 0.4156 - val_accuracy: 0.9514 - val_loss: 0.4072
# Epoch 31/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9576 - loss: 0.4074 - val_accuracy: 0.9591 - val_loss: 0.4031
# Epoch 32/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9589 - loss: 0.4045 - val_accuracy: 0.9514 - val_loss: 0.4003
# Epoch 33/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9545 - loss: 0.4042 - val_accuracy: 0.9591 - val_loss: 0.3967
# Epoch 34/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9623 - loss: 0.3959 - val_accuracy: 0.9533 - val_loss: 0.3941
# Epoch 35/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9587 - loss: 0.3965 - val_accuracy: 0.9533 - val_loss: 0.3916
# Epoch 36/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9529 - loss: 0.3961 - val_accuracy: 0.9591 - val_loss: 0.3886
# Epoch 37/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9613 - loss: 0.3876 - val_accuracy: 0.9533 - val_loss: 0.3865
# Epoch 38/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9574 - loss: 0.3884 - val_accuracy: 0.9533 - val_loss: 0.3843
# Epoch 39/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9598 - loss: 0.3848 - val_accuracy: 0.9611 - val_loss: 0.3819
# Epoch 40/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9530 - loss: 0.3896 - val_accuracy: 0.9572 - val_loss: 0.3799
# Epoch 41/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9586 - loss: 0.3812 - val_accuracy: 0.9533 - val_loss: 0.3787
# Epoch 42/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9619 - loss: 0.3757 - val_accuracy: 0.9591 - val_loss: 0.3757
# Epoch 43/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9577 - loss: 0.3783 - val_accuracy: 0.9591 - val_loss: 0.3737
# Epoch 44/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9576 - loss: 0.3744 - val_accuracy: 0.9533 - val_loss: 0.3726
# Epoch 45/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9631 - loss: 0.3705 - val_accuracy: 0.9591 - val_loss: 0.3701
# Epoch 46/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9547 - loss: 0.3746 - val_accuracy: 0.9533 - val_loss: 0.3697
# Epoch 47/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9555 - loss: 0.3712 - val_accuracy: 0.9591 - val_loss: 0.3670
# Epoch 48/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9578 - loss: 0.3690 - val_accuracy: 0.9533 - val_loss: 0.3670
# Epoch 49/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9613 - loss: 0.3645 - val_accuracy: 0.9572 - val_loss: 0.3645
# Epoch 50/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9622 - loss: 0.3620 - val_accuracy: 0.9591 - val_loss: 0.3621
# Epoch 51/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9596 - loss: 0.3642 - val_accuracy: 0.9611 - val_loss: 0.3608
# Epoch 52/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9576 - loss: 0.3643 - val_accuracy: 0.9572 - val_loss: 0.3605
# Epoch 53/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9580 - loss: 0.3595 - val_accuracy: 0.9533 - val_loss: 0.3602
# Epoch 54/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9565 - loss: 0.3599 - val_accuracy: 0.9611 - val_loss: 0.3564
# Epoch 55/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9590 - loss: 0.3595 - val_accuracy: 0.9572 - val_loss: 0.3566
# Epoch 56/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9630 - loss: 0.3531 - val_accuracy: 0.9591 - val_loss: 0.3540
# Epoch 57/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9598 - loss: 0.3526 - val_accuracy: 0.9611 - val_loss: 0.3524
# Epoch 58/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9586 - loss: 0.3531 - val_accuracy: 0.9591 - val_loss: 0.3519
# Epoch 59/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9569 - loss: 0.3515 - val_accuracy: 0.9591 - val_loss: 0.3506
# Epoch 60/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9588 - loss: 0.3498 - val_accuracy: 0.9611 - val_loss: 0.3487
# Epoch 61/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9587 - loss: 0.3525 - val_accuracy: 0.9591 - val_loss: 0.3481
# Epoch 62/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9599 - loss: 0.3505 - val_accuracy: 0.9611 - val_loss: 0.3466
# Epoch 63/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9589 - loss: 0.3467 - val_accuracy: 0.9591 - val_loss: 0.3458
# Epoch 64/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9605 - loss: 0.3466 - val_accuracy: 0.9591 - val_loss: 0.3448
# Epoch 65/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9549 - loss: 0.3469 - val_accuracy: 0.9611 - val_loss: 0.3433
# Epoch 66/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9656 - loss: 0.3395 - val_accuracy: 0.9611 - val_loss: 0.3422
# Epoch 67/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9682 - loss: 0.3343 - val_accuracy: 0.9611 - val_loss: 0.3414
# Epoch 68/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9701 - loss: 0.3310 - val_accuracy: 0.9572 - val_loss: 0.3414
# Epoch 69/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9571 - loss: 0.3394 - val_accuracy: 0.9591 - val_loss: 0.3393
# Epoch 70/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9661 - loss: 0.3371 - val_accuracy: 0.9591 - val_loss: 0.3386
# Epoch 71/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9727 - loss: 0.3275 - val_accuracy: 0.9611 - val_loss: 0.3360
# Epoch 72/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9578 - loss: 0.3386 - val_accuracy: 0.9611 - val_loss: 0.3361
# Epoch 73/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9565 - loss: 0.3373 - val_accuracy: 0.9572 - val_loss: 0.3355
# Epoch 74/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9709 - loss: 0.3250 - val_accuracy: 0.9630 - val_loss: 0.3322
# Epoch 75/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9635 - loss: 0.3317 - val_accuracy: 0.9572 - val_loss: 0.3344
# Epoch 76/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9550 - loss: 0.3346 - val_accuracy: 0.9630 - val_loss: 0.3304
# Epoch 77/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9678 - loss: 0.3270 - val_accuracy: 0.9611 - val_loss: 0.3302
# Epoch 78/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9661 - loss: 0.3251 - val_accuracy: 0.9591 - val_loss: 0.3296
# Epoch 79/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9638 - loss: 0.3267 - val_accuracy: 0.9591 - val_loss: 0.3305
# Epoch 80/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9677 - loss: 0.3223 - val_accuracy: 0.9630 - val_loss: 0.3257
# Epoch 81/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9602 - loss: 0.3273 - val_accuracy: 0.9630 - val_loss: 0.3257
# Epoch 82/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9649 - loss: 0.3240 - val_accuracy: 0.9630 - val_loss: 0.3241
# Epoch 83/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9624 - loss: 0.3235 - val_accuracy: 0.9591 - val_loss: 0.3253
# Epoch 84/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9616 - loss: 0.3234 - val_accuracy: 0.9591 - val_loss: 0.3245
# Epoch 85/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9621 - loss: 0.3190 - val_accuracy: 0.9630 - val_loss: 0.3221
# Epoch 86/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9613 - loss: 0.3190 - val_accuracy: 0.9630 - val_loss: 0.3200
# Epoch 87/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9592 - loss: 0.3194 - val_accuracy: 0.9630 - val_loss: 0.3193
# Epoch 88/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9675 - loss: 0.3160 - val_accuracy: 0.9630 - val_loss: 0.3186
# Epoch 89/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9620 - loss: 0.3162 - val_accuracy: 0.9611 - val_loss: 0.3180
# Epoch 90/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9632 - loss: 0.3177 - val_accuracy: 0.9611 - val_loss: 0.3188
# Epoch 91/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9620 - loss: 0.3167 - val_accuracy: 0.9611 - val_loss: 0.3180
# Epoch 92/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9596 - loss: 0.3189 - val_accuracy: 0.9630 - val_loss: 0.3146
# Epoch 93/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9586 - loss: 0.3159 - val_accuracy: 0.9611 - val_loss: 0.3153
# Epoch 94/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9682 - loss: 0.3112 - val_accuracy: 0.9630 - val_loss: 0.3129
# Epoch 95/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9635 - loss: 0.3102 - val_accuracy: 0.9611 - val_loss: 0.3150
# Epoch 96/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9730 - loss: 0.3016 - val_accuracy: 0.9630 - val_loss: 0.3102
# Epoch 97/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9741 - loss: 0.2996 - val_accuracy: 0.9611 - val_loss: 0.3101
# Epoch 98/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9663 - loss: 0.3074 - val_accuracy: 0.9611 - val_loss: 0.3109
# Epoch 99/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9655 - loss: 0.3066 - val_accuracy: 0.9611 - val_loss: 0.3103
# Epoch 100/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9693 - loss: 0.3006 - val_accuracy: 0.9611 - val_loss: 0.3076
# Epoch 101/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9680 - loss: 0.3035 - val_accuracy: 0.9630 - val_loss: 0.3058
# Epoch 102/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9675 - loss: 0.3030 - val_accuracy: 0.9611 - val_loss: 0.3088
# Epoch 103/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9707 - loss: 0.3012 - val_accuracy: 0.9611 - val_loss: 0.3066
# Epoch 104/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9736 - loss: 0.2970 - val_accuracy: 0.9650 - val_loss: 0.3028
# Epoch 105/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9762 - loss: 0.2902 - val_accuracy: 0.9611 - val_loss: 0.3033
# Epoch 106/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9725 - loss: 0.2923 - val_accuracy: 0.9611 - val_loss: 0.3050
# Epoch 107/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9711 - loss: 0.2928 - val_accuracy: 0.9650 - val_loss: 0.2997
# Epoch 108/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9691 - loss: 0.2956 - val_accuracy: 0.9553 - val_loss: 0.3062
# Epoch 109/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9657 - loss: 0.2947 - val_accuracy: 0.9611 - val_loss: 0.2996
# Epoch 110/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9668 - loss: 0.2947 - val_accuracy: 0.9611 - val_loss: 0.2990
# Epoch 111/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9718 - loss: 0.2907 - val_accuracy: 0.9611 - val_loss: 0.3016
# Epoch 112/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9662 - loss: 0.2965 - val_accuracy: 0.9611 - val_loss: 0.2987
# Epoch 113/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9653 - loss: 0.2975 - val_accuracy: 0.9630 - val_loss: 0.2956
# Epoch 114/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9757 - loss: 0.2857 - val_accuracy: 0.9572 - val_loss: 0.3007
# Epoch 115/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9602 - loss: 0.2987 - val_accuracy: 0.9611 - val_loss: 0.2960
# Epoch 116/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9675 - loss: 0.2904 - val_accuracy: 0.9611 - val_loss: 0.2941
# Epoch 117/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9694 - loss: 0.2883 - val_accuracy: 0.9611 - val_loss: 0.2936
# Epoch 118/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9651 - loss: 0.2914 - val_accuracy: 0.9611 - val_loss: 0.2927
# Epoch 119/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9696 - loss: 0.2832 - val_accuracy: 0.9611 - val_loss: 0.2927
# Epoch 120/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9737 - loss: 0.2809 - val_accuracy: 0.9630 - val_loss: 0.2901
# Epoch 121/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9746 - loss: 0.2792 - val_accuracy: 0.9650 - val_loss: 0.2883
# Epoch 122/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9745 - loss: 0.2792 - val_accuracy: 0.9611 - val_loss: 0.2908
# Epoch 123/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9700 - loss: 0.2762 - val_accuracy: 0.9611 - val_loss: 0.2900
# Epoch 124/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9707 - loss: 0.2820 - val_accuracy: 0.9611 - val_loss: 0.2891
# Epoch 125/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9616 - loss: 0.2873 - val_accuracy: 0.9611 - val_loss: 0.2876
# Epoch 126/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9770 - loss: 0.2722 - val_accuracy: 0.9650 - val_loss: 0.2847
# Epoch 127/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9680 - loss: 0.2838 - val_accuracy: 0.9591 - val_loss: 0.2880
# Epoch 128/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9663 - loss: 0.2840 - val_accuracy: 0.9611 - val_loss: 0.2860
# Epoch 129/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9688 - loss: 0.2792 - val_accuracy: 0.9611 - val_loss: 0.2842
# Epoch 130/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9782 - loss: 0.2699 - val_accuracy: 0.9591 - val_loss: 0.2856
# Epoch 131/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9639 - loss: 0.2790 - val_accuracy: 0.9611 - val_loss: 0.2823
# Epoch 132/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9787 - loss: 0.2684 - val_accuracy: 0.9630 - val_loss: 0.2812
# Epoch 133/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9746 - loss: 0.2687 - val_accuracy: 0.9630 - val_loss: 0.2802
# Epoch 134/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9641 - loss: 0.2799 - val_accuracy: 0.9591 - val_loss: 0.2836
# Epoch 135/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9685 - loss: 0.2733 - val_accuracy: 0.9611 - val_loss: 0.2793
# Epoch 136/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9727 - loss: 0.2693 - val_accuracy: 0.9630 - val_loss: 0.2773
# Epoch 137/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9683 - loss: 0.2759 - val_accuracy: 0.9611 - val_loss: 0.2783
# Epoch 138/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9717 - loss: 0.2691 - val_accuracy: 0.9630 - val_loss: 0.2764
# Epoch 139/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9715 - loss: 0.2668 - val_accuracy: 0.9630 - val_loss: 0.2758
# Epoch 140/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9693 - loss: 0.2690 - val_accuracy: 0.9630 - val_loss: 0.2756
# Epoch 141/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9741 - loss: 0.2652 - val_accuracy: 0.9630 - val_loss: 0.2743
# Epoch 142/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9747 - loss: 0.2618 - val_accuracy: 0.9630 - val_loss: 0.2737
# Epoch 143/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9738 - loss: 0.2664 - val_accuracy: 0.9611 - val_loss: 0.2758
# Epoch 144/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9724 - loss: 0.2656 - val_accuracy: 0.9630 - val_loss: 0.2739
# Epoch 145/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9686 - loss: 0.2671 - val_accuracy: 0.9630 - val_loss: 0.2713
# Epoch 146/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9735 - loss: 0.2625 - val_accuracy: 0.9630 - val_loss: 0.2719
# Epoch 147/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9721 - loss: 0.2613 - val_accuracy: 0.9611 - val_loss: 0.2733
# Epoch 148/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9744 - loss: 0.2600 - val_accuracy: 0.9689 - val_loss: 0.2680
# Epoch 149/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9677 - loss: 0.2667 - val_accuracy: 0.9630 - val_loss: 0.2704
# Epoch 150/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9743 - loss: 0.2589 - val_accuracy: 0.9650 - val_loss: 0.2673
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ ?                      │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │        86,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 273,608 (1.04 MB)
#  Trainable params: 91,202 (356.26 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 182,406 (712.53 KB)

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
img = tf.keras.utils.load_img(
    "samples/29.jpg", target_size=(img_height, img_width), color_mode="rgb"
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
print(predictions)
model.save("trained.keras")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# This image most likely belongs to eyes_closed with a 77.75 percent confidence.
# [[ 0.63255167 -0.61852926]]
